# %% [markdown]
# ##### Delete folder before starting

# %%
# i asked gpt to write this code

import shutil
import os

def delete_folder(folder_path):
    if os.path.exists(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f"Folder '{folder_path}' deleted successfully.")
        except OSError as e:
            print(f"Error: {e}")
    else:
        print(f"Folder '{folder_path}' does not exist.")

# %%
# train
folder_to_delete = "Apple/train"
delete_folder(folder_to_delete)

# val
folder_to_delete = "Apple/val"
delete_folder(folder_to_delete)
# Out:
# Folder 'Apple/train' deleted successfully.
# Folder 'Apple/val' deleted successfully.

# %% [markdown]
# # Code

# %%
import os 
dir = 'Apple' # this read fodler
print(os.listdir(dir))
# Out:
# ['AlternariaBoltch', 'AppleScab', 'BlackRot', 'CedarAppleRust', 'Disease', 'Healthy', 'Rust']

# %%
# labels from folder in directory yoooo
labels = os.listdir(dir)
labels.remove("Disease")
labels.remove("Healthy")
labels
# Out:
# ['AlternariaBoltch', 'AppleScab', 'BlackRot', 'CedarAppleRust', 'Rust']

# %%
# import
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import scipy as sp
import itertools
import zipfile
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, MaxPool2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# m8 delete later, should check on it

# %%
'''
Abbreviation (so i don't need to write long name)

AlternariaBoltch = boltch
AppleScab = scab
BlackRot = brot
CedarAppleRust = carust
Healthy = healthy
Rust = rust
'''

boltch_dir = os.path.join(dir, 'AlternariaBoltch')
scab_dir = os.path.join(dir, 'AppleScab')
brot_dir = os.path.join(dir, 'BlackRot')
carust_dir = os.path.join(dir, 'CedarAppleRust')
# healthy_dir = os.path.join(dir, 'Healthy')
rust_dir = os.path.join(dir, 'Rust')

boltch = os.listdir(boltch_dir)
scab = os.listdir(scab_dir)
brot = os.listdir(brot_dir)
carust = os.listdir(carust_dir)
# healthy = os.listdir(healthy_dir)
rust = os.listdir(rust_dir)

# %%
import random
import shutil

# Function split
def split_data(src, train_dst, val_dst, split_ratio=0.6):
    files = os.listdir(src)
    random.shuffle(files)

    split_index = int(len(files) * split_ratio)

    train_files = files[:split_index]
    val_files = files[split_index:]

    for file in train_files:
        shutil.copy(os.path.join(src, file), os.path.join(train_dst, file))

    for file in val_files:
        shutil.copy(os.path.join(src, file), os.path.join(val_dst, file))

# %%
train_dir = os.path.join(dir, 'train')
val_dir = os.path.join(dir, 'val')

# only use it once
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

os.listdir('Apple/train')
os.listdir('Apple/val')
# Out:
# []

# %%
# only use it once
for i in labels:
    os.makedirs(os.path.join(train_dir, i), exist_ok=True)
    os.makedirs(os.path.join(val_dir, i), exist_ok=True)

# %%
# Splitting the data, i hope someone made a better code for this :)
split_data(boltch_dir, os.path.join(train_dir, 'AlternariaBoltch'), os.path.join(val_dir, 'AlternariaBoltch'))
split_data(scab_dir, os.path.join(train_dir, 'AppleScab'), os.path.join(val_dir, 'AppleScab'))
split_data(brot_dir, os.path.join(train_dir, 'BlackRot'), os.path.join(val_dir, 'BlackRot'))
split_data(carust_dir, os.path.join(train_dir, 'CedarAppleRust'), os.path.join(val_dir, 'CedarAppleRust'))
# split_data(healthy_dir, os.path.join(train_dir, 'Healthy'), os.path.join(val_dir, 'Healthy'))
split_data(rust_dir, os.path.join(train_dir, 'Rust'), os.path.join(val_dir, 'Rust'))

# %%
# ImageDataGenerator
train_gen = ImageDataGenerator(rescale=1.0/256.0, 
                            zoom_range=0.4, 
                            rotation_range=30,
                            horizontal_flip=True, 
                            vertical_flip=True, 
                            shear_range=0.3, 
                            fill_mode='nearest',
                            width_shift_range=0.2, 
                            height_shift_range=0.2, 
                            validation_split=0.2)
val_gen = ImageDataGenerator(rescale=1.0/256.0,
                            validation_split=0.2)

# %%
train_dataset = train_gen.flow_from_directory(train_dir, 
                                            target_size=(256, 256), 
                                            color_mode="grayscale",
                                            class_mode='categorical', 
                                            batch_size=32)
val_dataset = val_gen.flow_from_directory(val_dir, 
                                        target_size=(256, 256), 
                                        color_mode="grayscale",
                                        class_mode='categorical', 
                                        batch_size=32,
                                        subset='validation')
# Out:
# Found 1250 images belonging to 5 classes.
# Found 164 images belonging to 5 classes.

# %%
print(train_dataset.class_indices)
print(val_dataset.class_indices)
# Out:
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Rust': 4}
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Rust': 4}

# %%
NUM_TRAIN_DATA = train_dataset.n
NUM_VALID_DATA = val_dataset.n

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=32, activation='relu', input_shape=(256, 256, 1), padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=32, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    # Flatten
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=5, activation='softmax'),
])

monitor = EarlyStopping(monitor='val_accuracy',
                        patience=2,
                        verbose=1,
                        mode='max',
                        restore_best_weights=True)

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)      320
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)      18496
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 128)       73856
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_3 (Dense)             (None, 256)               16777472
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 17,982,693
# Trainable params: 17,982,693
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 80
# a

# %%
history = model.fit(train_dataset, 
                    steps_per_epoch=NUM_TRAIN_DATA//BATCH_SIZE,
                    validation_data=val_dataset,
                    validation_steps=5,
                    epochs=EPOCHS,
                    verbose=1)
# Out:
# Epoch 1/80
# 39/39 [==============================] - 133s 3s/step - loss: 1.8078 - accuracy: 0.2192 - val_loss: 1.5899 - val_accuracy: 0.2250
# Epoch 2/80
# 39/39 [==============================] - 133s 3s/step - loss: 1.5064 - accuracy: 0.3046 - val_loss: 1.6051 - val_accuracy: 0.2812
# Epoch 3/80
# 39/39 [==============================] - 127s 3s/step - loss: 2.7730 - accuracy: 0.3793 - val_loss: 1.6692 - val_accuracy: 0.2000
# Epoch 4/80
# 39/39 [==============================] - 130s 3s/step - loss: 1.2337 - accuracy: 0.4844 - val_loss: 1.4055 - val_accuracy: 0.5250
# Epoch 5/80
# 39/39 [==============================] - 132s 3s/step - loss: 1.1749 - accuracy: 0.4877 - val_loss: 1.4645 - val_accuracy: 0.4375
# Epoch 6/80
# 39/39 [==============================] - 133s 3s/step - loss: 1.1357 - accuracy: 0.5304 - val_loss: 1.3032 - val_accuracy: 0.5688
# Epoch 7/80
# 39/39 [==============================] - 135s 3s/step - loss: 1.1102 - accuracy: 0.5558 - val_loss: 1.6191 - val_accuracy: 0.2750
# Epoch 8/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.9764 - accuracy: 0.5921 - val_loss: 0.8999 - val_accuracy: 0.6250
# Epoch 9/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.9707 - accuracy: 0.6067 - val_loss: 1.1483 - val_accuracy: 0.5125
# Epoch 10/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.9794 - accuracy: 0.5961 - val_loss: 0.8829 - val_accuracy: 0.5750
# Epoch 11/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.9465 - accuracy: 0.6273 - val_loss: 0.7713 - val_accuracy: 0.6875
# Epoch 12/80
# 39/39 [==============================] - 131s 3s/step - loss: 0.9260 - accuracy: 0.6437 - val_loss: 0.7411 - val_accuracy: 0.7063
# Epoch 13/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.8688 - accuracy: 0.6519 - val_loss: 0.8712 - val_accuracy: 0.6438
# Epoch 14/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.8196 - accuracy: 0.6749 - val_loss: 0.7485 - val_accuracy: 0.6750
# Epoch 15/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.9240 - accuracy: 0.6371 - val_loss: 0.7269 - val_accuracy: 0.7000
# Epoch 16/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.8578 - accuracy: 0.6683 - val_loss: 0.9679 - val_accuracy: 0.5688
# Epoch 17/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.8324 - accuracy: 0.6552 - val_loss: 0.6053 - val_accuracy: 0.7250
# Epoch 18/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.8061 - accuracy: 0.6658 - val_loss: 0.6874 - val_accuracy: 0.6687
# Epoch 19/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.7740 - accuracy: 0.6856 - val_loss: 0.6492 - val_accuracy: 0.7312
# Epoch 20/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.7810 - accuracy: 0.6839 - val_loss: 0.6648 - val_accuracy: 0.7063
# Epoch 21/80
# 39/39 [==============================] - 131s 3s/step - loss: 0.7812 - accuracy: 0.6814 - val_loss: 0.6309 - val_accuracy: 0.7188
# Epoch 22/80
# 39/39 [==============================] - 134s 3s/step - loss: 0.7428 - accuracy: 0.6880 - val_loss: 0.5733 - val_accuracy: 0.7250
# Epoch 23/80
# 39/39 [==============================] - 136s 3s/step - loss: 0.7261 - accuracy: 0.6921 - val_loss: 0.6454 - val_accuracy: 0.7437
# Epoch 24/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.7251 - accuracy: 0.7184 - val_loss: 1.1859 - val_accuracy: 0.5063
# Epoch 25/80
# 39/39 [==============================] - 134s 3s/step - loss: 0.7357 - accuracy: 0.7044 - val_loss: 0.5552 - val_accuracy: 0.7312
# Epoch 26/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.7036 - accuracy: 0.7217 - val_loss: 0.5517 - val_accuracy: 0.7812
# Epoch 27/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.6955 - accuracy: 0.7241 - val_loss: 0.7263 - val_accuracy: 0.6625
# Epoch 28/80
# 39/39 [==============================] - 136s 3s/step - loss: 0.6834 - accuracy: 0.7258 - val_loss: 0.5829 - val_accuracy: 0.7688
# Epoch 29/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.6868 - accuracy: 0.7274 - val_loss: 0.7513 - val_accuracy: 0.6500
# Epoch 30/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.6659 - accuracy: 0.7447 - val_loss: 0.5095 - val_accuracy: 0.7625
# Epoch 31/80
# 39/39 [==============================] - 136s 3s/step - loss: 0.6997 - accuracy: 0.7151 - val_loss: 0.5156 - val_accuracy: 0.7812
# Epoch 32/80
# 39/39 [==============================] - 142s 4s/step - loss: 0.6452 - accuracy: 0.7414 - val_loss: 0.6422 - val_accuracy: 0.6812
# Epoch 33/80
# 39/39 [==============================] - 139s 4s/step - loss: 0.6278 - accuracy: 0.7529 - val_loss: 0.3772 - val_accuracy: 0.8375
# Epoch 34/80
# 39/39 [==============================] - 149s 4s/step - loss: 0.6561 - accuracy: 0.7644 - val_loss: 0.6908 - val_accuracy: 0.6875
# Epoch 35/80
# 39/39 [==============================] - 151s 4s/step - loss: 0.6043 - accuracy: 0.7644 - val_loss: 0.8063 - val_accuracy: 0.7250
# Epoch 36/80
# 39/39 [==============================] - 145s 4s/step - loss: 0.6066 - accuracy: 0.7726 - val_loss: 0.5656 - val_accuracy: 0.7812
# Epoch 37/80
# 39/39 [==============================] - 156s 4s/step - loss: 0.6203 - accuracy: 0.7512 - val_loss: 0.3835 - val_accuracy: 0.8375
# Epoch 38/80
# 39/39 [==============================] - 156s 4s/step - loss: 0.5990 - accuracy: 0.7701 - val_loss: 0.5147 - val_accuracy: 0.7625
# Epoch 39/80
# 39/39 [==============================] - 142s 4s/step - loss: 0.5314 - accuracy: 0.7857 - val_loss: 0.4532 - val_accuracy: 0.8250
# Epoch 40/80
# 39/39 [==============================] - 143s 4s/step - loss: 0.5421 - accuracy: 0.7882 - val_loss: 0.3978 - val_accuracy: 0.8500
# Epoch 41/80
# 39/39 [==============================] - 139s 4s/step - loss: 0.5348 - accuracy: 0.7964 - val_loss: 0.4851 - val_accuracy: 0.8000
# Epoch 42/80
# 39/39 [==============================] - 151s 4s/step - loss: 0.5696 - accuracy: 0.7808 - val_loss: 0.2769 - val_accuracy: 0.8750
# Epoch 43/80
# 39/39 [==============================] - 146s 4s/step - loss: 0.4961 - accuracy: 0.8136 - val_loss: 0.2958 - val_accuracy: 0.8750
# Epoch 44/80
# 39/39 [==============================] - 144s 4s/step - loss: 0.5061 - accuracy: 0.8021 - val_loss: 0.3761 - val_accuracy: 0.8625
# Epoch 45/80
# 39/39 [==============================] - 144s 4s/step - loss: 0.5385 - accuracy: 0.8005 - val_loss: 0.4796 - val_accuracy: 0.8000
# Epoch 46/80
# 39/39 [==============================] - 148s 4s/step - loss: 0.5023 - accuracy: 0.7923 - val_loss: 0.3527 - val_accuracy: 0.8562
# Epoch 47/80
# 39/39 [==============================] - 143s 4s/step - loss: 0.5342 - accuracy: 0.8087 - val_loss: 0.4136 - val_accuracy: 0.8188
# Epoch 48/80
# 39/39 [==============================] - 139s 4s/step - loss: 0.4897 - accuracy: 0.8144 - val_loss: 0.3731 - val_accuracy: 0.8375
# Epoch 49/80
# 39/39 [==============================] - 143s 4s/step - loss: 0.4582 - accuracy: 0.8169 - val_loss: 0.3059 - val_accuracy: 0.8625
# Epoch 50/80
# 39/39 [==============================] - 147s 4s/step - loss: 0.4781 - accuracy: 0.8276 - val_loss: 0.3609 - val_accuracy: 0.8375
# Epoch 51/80
# 39/39 [==============================] - 149s 4s/step - loss: 0.4399 - accuracy: 0.8399 - val_loss: 0.4248 - val_accuracy: 0.8625
# Epoch 52/80
# 39/39 [==============================] - 148s 4s/step - loss: 0.4775 - accuracy: 0.8389 - val_loss: 0.3294 - val_accuracy: 0.8813
# Epoch 53/80
# 39/39 [==============================] - 147s 4s/step - loss: 0.4507 - accuracy: 0.8448 - val_loss: 0.2969 - val_accuracy: 0.8938
# Epoch 54/80
# 39/39 [==============================] - 144s 4s/step - loss: 0.5058 - accuracy: 0.8202 - val_loss: 0.4712 - val_accuracy: 0.8438
# Epoch 55/80
# 39/39 [==============================] - 145s 4s/step - loss: 0.3920 - accuracy: 0.8563 - val_loss: 0.2338 - val_accuracy: 0.9125
# Epoch 56/80
# 39/39 [==============================] - 146s 4s/step - loss: 0.4266 - accuracy: 0.8432 - val_loss: 0.4245 - val_accuracy: 0.8438
# Epoch 57/80
# 39/39 [==============================] - 146s 4s/step - loss: 0.4238 - accuracy: 0.8374 - val_loss: 0.2728 - val_accuracy: 0.8813
# Epoch 58/80
# 39/39 [==============================] - 142s 4s/step - loss: 0.4888 - accuracy: 0.8213 - val_loss: 0.3259 - val_accuracy: 0.8813
# Epoch 59/80
# 39/39 [==============================] - 136s 3s/step - loss: 0.3975 - accuracy: 0.8514 - val_loss: 0.4900 - val_accuracy: 0.7750
# Epoch 60/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3705 - accuracy: 0.8563 - val_loss: 0.5864 - val_accuracy: 0.8000
# Epoch 61/80
# 39/39 [==============================] - 134s 3s/step - loss: 0.4124 - accuracy: 0.8612 - val_loss: 0.3646 - val_accuracy: 0.8625
# Epoch 62/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.4412 - accuracy: 0.8366 - val_loss: 0.3159 - val_accuracy: 0.8625
# Epoch 63/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3830 - accuracy: 0.8612 - val_loss: 0.4006 - val_accuracy: 0.8375
# Epoch 64/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.4217 - accuracy: 0.8456 - val_loss: 0.3009 - val_accuracy: 0.9125
# Epoch 65/80
# 39/39 [==============================] - 138s 4s/step - loss: 0.3555 - accuracy: 0.8686 - val_loss: 0.5487 - val_accuracy: 0.8188
# Epoch 66/80
# 39/39 [==============================] - 139s 4s/step - loss: 0.3936 - accuracy: 0.8550 - val_loss: 0.3220 - val_accuracy: 0.8813
# Epoch 67/80
# 39/39 [==============================] - 134s 3s/step - loss: 0.3699 - accuracy: 0.8752 - val_loss: 0.2984 - val_accuracy: 0.8813
# Epoch 68/80
# 39/39 [==============================] - 134s 3s/step - loss: 0.4026 - accuracy: 0.8695 - val_loss: 1.1248 - val_accuracy: 0.6187
# Epoch 69/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.4082 - accuracy: 0.8596 - val_loss: 0.4044 - val_accuracy: 0.8313
# Epoch 70/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3716 - accuracy: 0.8588 - val_loss: 0.5524 - val_accuracy: 0.8125
# Epoch 71/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3472 - accuracy: 0.8834 - val_loss: 0.3587 - val_accuracy: 0.8875
# Epoch 72/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.4357 - accuracy: 0.8506 - val_loss: 0.2597 - val_accuracy: 0.8750
# Epoch 73/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.3375 - accuracy: 0.8678 - val_loss: 0.4411 - val_accuracy: 0.8313
# Epoch 74/80
# 39/39 [==============================] - 132s 3s/step - loss: 0.3678 - accuracy: 0.8604 - val_loss: 1.4872 - val_accuracy: 0.8188
# Epoch 75/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.4068 - accuracy: 0.8621 - val_loss: 0.4402 - val_accuracy: 0.8625
# Epoch 76/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.3587 - accuracy: 0.8662 - val_loss: 0.4179 - val_accuracy: 0.8750
# Epoch 77/80
# 39/39 [==============================] - 133s 3s/step - loss: 0.3330 - accuracy: 0.8727 - val_loss: 0.6804 - val_accuracy: 0.8250
# Epoch 78/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3729 - accuracy: 0.8662 - val_loss: 0.4846 - val_accuracy: 0.8375
# Epoch 79/80
# 39/39 [==============================] - 135s 3s/step - loss: 0.3381 - accuracy: 0.8818 - val_loss: 0.9355 - val_accuracy: 0.7063
# Epoch 80/80
# 39/39 [==============================] - 136s 3s/step - loss: 0.4074 - accuracy: 0.8580 - val_loss: 0.9940 - val_accuracy: 0.6875

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = model.predict(val_dataset, steps=len(val_dataset))
predicted_labels = np.argmax(predictions, axis=1)
true_labels = val_dataset.classes
cm = confusion_matrix(true_labels, predicted_labels)

# Create a seaborn heatmap
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 6/6 [==============================] - 4s 598ms/step

# %%
model.save('attempt_007.h5')

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
