# %% [markdown]
# ##### Delete folder before starting

# %%
# i asked gpt to write this code

import shutil
import os

def delete_folder(folder_path):
    if os.path.exists(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f"Folder '{folder_path}' deleted successfully.")
        except OSError as e:
            print(f"Error: {e}")
    else:
        print(f"Folder '{folder_path}' does not exist.")

# %%
# train
folder_to_delete = "Apple/train"
delete_folder(folder_to_delete)

# val
folder_to_delete = "Apple/val"
delete_folder(folder_to_delete)
# Out:
# Folder 'Apple/train' deleted successfully.
# Folder 'Apple/val' deleted successfully.

# %% [markdown]
# # Code

# %%
import os 
dir = 'Apple' # this read fodler
print(os.listdir(dir))
# Out:
# ['AlternariaBoltch', 'AppleScab', 'BlackRot', 'CedarAppleRust', 'Disease', 'Healthy', 'Rust']

# %%
# labels from folder in directory yoooo
labels = os.listdir(dir)
labels.remove("Disease")
labels
# Out:
# ['AlternariaBoltch',
#  'AppleScab',
#  'BlackRot',
#  'CedarAppleRust',
#  'Healthy',
#  'Rust']

# %%
# import
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import scipy as sp
import itertools
import zipfile
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, MaxPool2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# m8 delete later, should check on it

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.10.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
'''
Abbreviation (so i don't need to write long name)

AlternariaBoltch = boltch
AppleScab = scab
BlackRot = brot
CedarAppleRust = carust
Healthy = healthy
Rust = rust
'''

boltch_dir = os.path.join(dir, 'AlternariaBoltch')
scab_dir = os.path.join(dir, 'AppleScab')
brot_dir = os.path.join(dir, 'BlackRot')
carust_dir = os.path.join(dir, 'CedarAppleRust')
healthy_dir = os.path.join(dir, 'Healthy')
rust_dir = os.path.join(dir, 'Rust')

boltch = os.listdir(boltch_dir)
scab = os.listdir(scab_dir)
brot = os.listdir(brot_dir)
carust = os.listdir(carust_dir)
healthy = os.listdir(healthy_dir)
rust = os.listdir(rust_dir)

# %%
import random
import shutil

# Function split
def split_data(src, train_dst, val_dst, split_ratio=0.6):
    files = os.listdir(src)
    random.shuffle(files)

    split_index = int(len(files) * split_ratio)

    train_files = files[:split_index]
    val_files = files[split_index:]

    for file in train_files:
        shutil.copy(os.path.join(src, file), os.path.join(train_dst, file))

    for file in val_files:
        shutil.copy(os.path.join(src, file), os.path.join(val_dst, file))

# %%
train_dir = os.path.join(dir, 'train')
val_dir = os.path.join(dir, 'val')

# only use it once
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

os.listdir('Apple/train')
os.listdir('Apple/val')
# Out:
# []

# %%
# only use it once
for i in labels:
    os.makedirs(os.path.join(train_dir, i), exist_ok=True)
    os.makedirs(os.path.join(val_dir, i), exist_ok=True)

# %%
# Splitting the data, i hope someone made a better code for this :)
split_data(boltch_dir, os.path.join(train_dir, 'AlternariaBoltch'), os.path.join(val_dir, 'AlternariaBoltch'))
split_data(scab_dir, os.path.join(train_dir, 'AppleScab'), os.path.join(val_dir, 'AppleScab'))
split_data(brot_dir, os.path.join(train_dir, 'BlackRot'), os.path.join(val_dir, 'BlackRot'))
split_data(carust_dir, os.path.join(train_dir, 'CedarAppleRust'), os.path.join(val_dir, 'CedarAppleRust'))
split_data(healthy_dir, os.path.join(train_dir, 'Healthy'), os.path.join(val_dir, 'Healthy'))
split_data(rust_dir, os.path.join(train_dir, 'Rust'), os.path.join(val_dir, 'Rust'))

# %%
# ImageDataGenerator
train_gen = ImageDataGenerator(rescale=1.0/256.0, 
                            zoom_range=0.4, 
                            rotation_range=30,
                            horizontal_flip=True, 
                            vertical_flip=True, 
                            shear_range=0.3, 
                            fill_mode='nearest',
                            width_shift_range=0.2, 
                            height_shift_range=0.2, 
                            validation_split=0.2)
val_gen = ImageDataGenerator(rescale=1.0/256.0,
                            validation_split=0.2)

# %%
train_dataset = train_gen.flow_from_directory(train_dir, 
                                            target_size=(256, 256), 
                                            color_mode="rgb",
                                            class_mode='categorical', 
                                            batch_size=32)
val_dataset = val_gen.flow_from_directory(val_dir, 
                                        target_size=(256, 256), 
                                        color_mode="rgb",
                                        class_mode='categorical', 
                                        batch_size=32,
                                        subset='validation')
# Out:
# Found 1561 images belonging to 6 classes.
# Found 205 images belonging to 6 classes.

# %%
print(train_dataset.class_indices)
print(val_dataset.class_indices)
# Out:
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}

# %%
NUM_TRAIN_DATA = train_dataset.n
NUM_VALID_DATA = val_dataset.n

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=32, activation='relu', input_shape=(256, 256, 3), padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=32, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    # Flatten
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='softmax'),
])

monitor = EarlyStopping(monitor='val_accuracy',
                        patience=2,
                        verbose=1,
                        mode='max',
                        restore_best_weights=True)

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)      896
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)      18496
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 128)       73856
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_3 (Dense)             (None, 256)               16777472
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 17,983,398
# Trainable params: 17,983,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 64
# a

# %%
history = model.fit(train_dataset, 
                    steps_per_epoch=NUM_TRAIN_DATA//BATCH_SIZE,
                    validation_data=val_dataset,
                    validation_steps=5,
                    epochs=EPOCHS,
                    verbose=1)
# Out:
# Epoch 1/64
# 48/48 [==============================] - 176s 4s/step - loss: 2.0817 - accuracy: 0.1923 - val_loss: 1.7723 - val_accuracy: 0.1875
# Epoch 2/64
# 48/48 [==============================] - 183s 4s/step - loss: 1.6727 - accuracy: 0.2368 - val_loss: 1.8174 - val_accuracy: 0.2125
# Epoch 3/64
# 48/48 [==============================] - 176s 4s/step - loss: 1.7067 - accuracy: 0.2335 - val_loss: 1.7048 - val_accuracy: 0.2500
# Epoch 4/64
# 48/48 [==============================] - 163s 3s/step - loss: 1.6353 - accuracy: 0.2590 - val_loss: 1.8289 - val_accuracy: 0.1875
# Epoch 5/64
# 48/48 [==============================] - 166s 3s/step - loss: 1.6205 - accuracy: 0.2642 - val_loss: 2.1802 - val_accuracy: 0.1813
# Epoch 6/64
# 48/48 [==============================] - 165s 3s/step - loss: 1.5245 - accuracy: 0.3427 - val_loss: 1.7045 - val_accuracy: 0.4375
# Epoch 7/64
# 48/48 [==============================] - 165s 3s/step - loss: 1.5055 - accuracy: 0.3669 - val_loss: 1.4967 - val_accuracy: 0.3250
# Epoch 8/64
# 48/48 [==============================] - 166s 3s/step - loss: 1.4289 - accuracy: 0.4297 - val_loss: 1.1707 - val_accuracy: 0.5750
# Epoch 9/64
# 48/48 [==============================] - 166s 3s/step - loss: 1.2386 - accuracy: 0.5232 - val_loss: 1.1703 - val_accuracy: 0.6187
# Epoch 10/64
# 48/48 [==============================] - 167s 3s/step - loss: 1.1858 - accuracy: 0.5631 - val_loss: 1.0643 - val_accuracy: 0.5562
# Epoch 11/64
# 48/48 [==============================] - 167s 3s/step - loss: 1.1369 - accuracy: 0.5768 - val_loss: 1.3237 - val_accuracy: 0.6000
# Epoch 12/64
# 48/48 [==============================] - 169s 3s/step - loss: 0.9687 - accuracy: 0.6305 - val_loss: 0.9965 - val_accuracy: 0.5063
# Epoch 13/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.9572 - accuracy: 0.6442 - val_loss: 0.7543 - val_accuracy: 0.7125
# Epoch 14/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.9467 - accuracy: 0.6508 - val_loss: 0.7172 - val_accuracy: 0.7000
# Epoch 15/64
# 48/48 [==============================] - 164s 3s/step - loss: 0.8822 - accuracy: 0.6835 - val_loss: 0.7426 - val_accuracy: 0.6938
# Epoch 16/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.8694 - accuracy: 0.6691 - val_loss: 0.9535 - val_accuracy: 0.7063
# Epoch 17/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.8031 - accuracy: 0.7116 - val_loss: 0.8427 - val_accuracy: 0.7625
# Epoch 18/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.8041 - accuracy: 0.7181 - val_loss: 1.1209 - val_accuracy: 0.5500
# Epoch 19/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.7268 - accuracy: 0.7305 - val_loss: 0.7493 - val_accuracy: 0.7500
# Epoch 20/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.7410 - accuracy: 0.7332 - val_loss: 1.2255 - val_accuracy: 0.5625
# Epoch 21/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.7111 - accuracy: 0.7443 - val_loss: 0.6717 - val_accuracy: 0.7875
# Epoch 22/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.6876 - accuracy: 0.7508 - val_loss: 1.0025 - val_accuracy: 0.6562
# Epoch 23/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.6491 - accuracy: 0.7587 - val_loss: 0.6242 - val_accuracy: 0.7750
# Epoch 24/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.6808 - accuracy: 0.7534 - val_loss: 0.5055 - val_accuracy: 0.8188
# Epoch 25/64
# 48/48 [==============================] - 164s 3s/step - loss: 0.6426 - accuracy: 0.7626 - val_loss: 0.6121 - val_accuracy: 0.7625
# Epoch 26/64
# 48/48 [==============================] - 164s 3s/step - loss: 0.6218 - accuracy: 0.7717 - val_loss: 0.6644 - val_accuracy: 0.7812
# Epoch 27/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.6593 - accuracy: 0.7672 - val_loss: 0.5883 - val_accuracy: 0.7375
# Epoch 28/64
# 48/48 [==============================] - 169s 4s/step - loss: 0.5722 - accuracy: 0.7888 - val_loss: 0.6372 - val_accuracy: 0.7625
# Epoch 29/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.5615 - accuracy: 0.8012 - val_loss: 0.4994 - val_accuracy: 0.8125
# Epoch 30/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.6052 - accuracy: 0.7789 - val_loss: 0.7489 - val_accuracy: 0.7625
# Epoch 31/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.5751 - accuracy: 0.7953 - val_loss: 0.9242 - val_accuracy: 0.6438
# Epoch 32/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5584 - accuracy: 0.7946 - val_loss: 1.2693 - val_accuracy: 0.6250
# Epoch 33/64
# 48/48 [==============================] - 168s 3s/step - loss: 0.5647 - accuracy: 0.8038 - val_loss: 1.2413 - val_accuracy: 0.5500
# Epoch 34/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.5191 - accuracy: 0.8025 - val_loss: 0.6180 - val_accuracy: 0.7812
# Epoch 35/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5808 - accuracy: 0.8090 - val_loss: 0.6224 - val_accuracy: 0.7937
# Epoch 36/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5298 - accuracy: 0.8234 - val_loss: 0.9274 - val_accuracy: 0.6687
# Epoch 37/64
# 48/48 [==============================] - 168s 3s/step - loss: 0.5334 - accuracy: 0.8169 - val_loss: 0.9234 - val_accuracy: 0.6750
# Epoch 38/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.5754 - accuracy: 0.8084 - val_loss: 0.5774 - val_accuracy: 0.8062
# Epoch 39/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5095 - accuracy: 0.8208 - val_loss: 0.4400 - val_accuracy: 0.8813
# Epoch 40/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5355 - accuracy: 0.8064 - val_loss: 0.4841 - val_accuracy: 0.8438
# Epoch 41/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.5054 - accuracy: 0.8201 - val_loss: 0.9414 - val_accuracy: 0.7063
# Epoch 42/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.5207 - accuracy: 0.8090 - val_loss: 0.5502 - val_accuracy: 0.7937
# Epoch 43/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4836 - accuracy: 0.8267 - val_loss: 1.3493 - val_accuracy: 0.6250
# Epoch 44/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.5484 - accuracy: 0.8143 - val_loss: 0.4274 - val_accuracy: 0.8687
# Epoch 45/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.5049 - accuracy: 0.8208 - val_loss: 0.6477 - val_accuracy: 0.7937
# Epoch 46/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4613 - accuracy: 0.8528 - val_loss: 0.4145 - val_accuracy: 0.8250
# Epoch 47/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4954 - accuracy: 0.8254 - val_loss: 0.6394 - val_accuracy: 0.8188
# Epoch 48/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4925 - accuracy: 0.8332 - val_loss: 0.4962 - val_accuracy: 0.7937
# Epoch 49/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4431 - accuracy: 0.8535 - val_loss: 0.5453 - val_accuracy: 0.8000
# Epoch 50/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4874 - accuracy: 0.8313 - val_loss: 0.4496 - val_accuracy: 0.8188
# Epoch 51/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4796 - accuracy: 0.8332 - val_loss: 0.4081 - val_accuracy: 0.8313
# Epoch 52/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4657 - accuracy: 0.8385 - val_loss: 0.4747 - val_accuracy: 0.8438
# Epoch 53/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.5081 - accuracy: 0.8221 - val_loss: 0.5279 - val_accuracy: 0.8188
# Epoch 54/64
# 48/48 [==============================] - 165s 3s/step - loss: 0.4507 - accuracy: 0.8600 - val_loss: 0.5183 - val_accuracy: 0.8000
# Epoch 55/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4184 - accuracy: 0.8515 - val_loss: 0.4296 - val_accuracy: 0.8562
# Epoch 56/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4982 - accuracy: 0.8247 - val_loss: 0.5348 - val_accuracy: 0.8438
# Epoch 57/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4423 - accuracy: 0.8443 - val_loss: 0.5172 - val_accuracy: 0.7812
# Epoch 58/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4399 - accuracy: 0.8574 - val_loss: 0.7747 - val_accuracy: 0.7688
# Epoch 59/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4366 - accuracy: 0.8463 - val_loss: 0.4917 - val_accuracy: 0.8687
# Epoch 60/64
# 48/48 [==============================] - 166s 3s/step - loss: 0.4630 - accuracy: 0.8450 - val_loss: 0.6195 - val_accuracy: 0.8313
# Epoch 61/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4555 - accuracy: 0.8581 - val_loss: 0.4473 - val_accuracy: 0.8438
# Epoch 62/64
# 48/48 [==============================] - 167s 3s/step - loss: 0.4393 - accuracy: 0.8496 - val_loss: 0.4332 - val_accuracy: 0.8562
# Epoch 63/64
# 48/48 [==============================] - 168s 3s/step - loss: 0.4861 - accuracy: 0.8502 - val_loss: 0.6122 - val_accuracy: 0.8375
# Epoch 64/64
# 48/48 [==============================] - 168s 3s/step - loss: 0.4383 - accuracy: 0.8509 - val_loss: 0.4429 - val_accuracy: 0.8687

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = model.predict(val_dataset, steps=len(val_dataset))
predicted_labels = np.argmax(predictions, axis=1)
true_labels = val_dataset.classes
cm = confusion_matrix(true_labels, predicted_labels)

# Create a seaborn heatmap
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 7/7 [==============================] - 5s 622ms/step

# %%
model.save('attempt_006.h5')

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# i think 60 epochs is enough
