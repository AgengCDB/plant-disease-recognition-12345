# %%
# i delete a few healthy image (700)

# %% [markdown]
# ##### Delete folder before starting

# %%
# i asked gpt to write this code

import shutil
import os

def delete_folder(folder_path):
    if os.path.exists(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f"Folder '{folder_path}' deleted successfully.")
        except OSError as e:
            print(f"Error: {e}")
    else:
        print(f"Folder '{folder_path}' does not exist.")

# %%
# train
folder_to_delete = "Apple/train"
delete_folder(folder_to_delete)

# val
folder_to_delete = "Apple/val"
delete_folder(folder_to_delete)
# Out:
# Folder 'Apple/train' deleted successfully.
# Folder 'Apple/val' deleted successfully.

# %% [markdown]
# # Code

# %%
import os 
dir = 'Apple' # this read fodler
print(os.listdir(dir))
# Out:
# ['AlternariaBoltch', 'AppleScab', 'BlackRot', 'CedarAppleRust', 'Disease', 'Healthy', 'Rust']

# %%
# labels from folder in directory yoooo
labels = os.listdir(dir)
labels.remove("Disease")
labels
# Out:
# ['AlternariaBoltch',
#  'AppleScab',
#  'BlackRot',
#  'CedarAppleRust',
#  'Healthy',
#  'Rust']

# %%
# import
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import scipy as sp
import itertools
import zipfile
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, MaxPool2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# m8 delete later, should check on it

# %%
'''
Abbreviation (so i don't need to write long name)

AlternariaBoltch = boltch
AppleScab = scab
BlackRot = brot
CedarAppleRust = carust
Healthy = healthy
Rust = rust
'''

boltch_dir = os.path.join(dir, 'AlternariaBoltch')
scab_dir = os.path.join(dir, 'AppleScab')
brot_dir = os.path.join(dir, 'BlackRot')
carust_dir = os.path.join(dir, 'CedarAppleRust')
healthy_dir = os.path.join(dir, 'Healthy')
rust_dir = os.path.join(dir, 'Rust')

boltch = os.listdir(boltch_dir)
scab = os.listdir(scab_dir)
brot = os.listdir(brot_dir)
carust = os.listdir(carust_dir)
healthy = os.listdir(healthy_dir)
rust = os.listdir(rust_dir)

# %%
import random
import shutil

# Function split
def split_data(src, train_dst, val_dst, split_ratio=0.6):
    files = os.listdir(src)
    random.shuffle(files)

    split_index = int(len(files) * split_ratio)

    train_files = files[:split_index]
    val_files = files[split_index:]

    for file in train_files:
        shutil.copy(os.path.join(src, file), os.path.join(train_dst, file))

    for file in val_files:
        shutil.copy(os.path.join(src, file), os.path.join(val_dst, file))

# %%
train_dir = os.path.join(dir, 'train')
val_dir = os.path.join(dir, 'val')

# only use it once
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

os.listdir('Apple/train')
os.listdir('Apple/val')
# Out:
# []

# %%
# only use it once
for i in labels:
    os.makedirs(os.path.join(train_dir, i), exist_ok=True)
    os.makedirs(os.path.join(val_dir, i), exist_ok=True)

# %%
# Splitting the data, i hope someone made a better code for this :)
split_data(boltch_dir, os.path.join(train_dir, 'AlternariaBoltch'), os.path.join(val_dir, 'AlternariaBoltch'))
split_data(scab_dir, os.path.join(train_dir, 'AppleScab'), os.path.join(val_dir, 'AppleScab'))
split_data(brot_dir, os.path.join(train_dir, 'BlackRot'), os.path.join(val_dir, 'BlackRot'))
split_data(carust_dir, os.path.join(train_dir, 'CedarAppleRust'), os.path.join(val_dir, 'CedarAppleRust'))
split_data(healthy_dir, os.path.join(train_dir, 'Healthy'), os.path.join(val_dir, 'Healthy'))
split_data(rust_dir, os.path.join(train_dir, 'Rust'), os.path.join(val_dir, 'Rust'))

# %%
# ImageDataGenerator
train_gen = ImageDataGenerator(rescale=1.0/256.0, 
                            zoom_range=0.4, 
                            rotation_range=30,
                            horizontal_flip=True, 
                            vertical_flip=True, 
                            shear_range=0.3, 
                            fill_mode='nearest',
                            width_shift_range=0.2, 
                            height_shift_range=0.2, 
                            validation_split=0.2)
val_gen = ImageDataGenerator(rescale=1.0/256.0,
                            validation_split=0.2)

# %%
train_dataset = train_gen.flow_from_directory(train_dir, 
                                            target_size=(256, 256), 
                                            color_mode="rgb",
                                            class_mode='categorical', 
                                            batch_size=32)
val_dataset = val_gen.flow_from_directory(val_dir, 
                                        target_size=(256, 256), 
                                        color_mode="rgb",
                                        class_mode='categorical', 
                                        batch_size=32,
                                        subset='validation')
# Out:
# Found 1249 images belonging to 6 classes.
# Found 164 images belonging to 6 classes.

# %%
print(train_dataset.class_indices)
print(val_dataset.class_indices)
# Out:
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}

# %%
NUM_TRAIN_DATA = train_dataset.n
NUM_VALID_DATA = val_dataset.n

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=32, activation='relu', input_shape=(256, 256, 3), padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=32, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    # Flatten
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='softmax'),
])

monitor = EarlyStopping(monitor='val_accuracy',
                        patience=2,
                        verbose=1,
                        mode='max',
                        restore_best_weights=True)

# %%
# don't use this one

# model = Sequential()

# model.add(Conv2D(16, kernel_size=3, activation='relu', input_shape=(256, 256, 3)))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(32, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(64, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(128, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(7, activation='softmax'))

# model.summary()

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 256)       590080
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 256)               16777472
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 17,983,398
# Trainable params: 17,983,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 128
# a

# %%
history = model.fit(train_dataset, 
                    steps_per_epoch=NUM_TRAIN_DATA//BATCH_SIZE,
                    validation_data=val_dataset,
                    validation_steps=5,
                    epochs=EPOCHS,
                    verbose=1)
# Out:
# Epoch 1/128
# 39/39 [==============================] - 138s 4s/step - loss: 1.7332 - accuracy: 0.2588 - val_loss: 1.7509 - val_accuracy: 0.1750
# Epoch 2/128
# 39/39 [==============================] - 141s 4s/step - loss: 1.7291 - accuracy: 0.2621 - val_loss: 1.7455 - val_accuracy: 0.2438
# Epoch 3/128
# 39/39 [==============================] - 141s 4s/step - loss: 1.5454 - accuracy: 0.3164 - val_loss: 1.6762 - val_accuracy: 0.2625
# Epoch 4/128
# 39/39 [==============================] - 136s 3s/step - loss: 1.5878 - accuracy: 0.3246 - val_loss: 1.7344 - val_accuracy: 0.2313
# Epoch 5/128
# 39/39 [==============================] - 136s 3s/step - loss: 1.5355 - accuracy: 0.3429 - val_loss: 2.2360 - val_accuracy: 0.2562
# Epoch 6/128
# 39/39 [==============================] - 140s 4s/step - loss: 1.5510 - accuracy: 0.3599 - val_loss: 1.7013 - val_accuracy: 0.4313
# Epoch 7/128
# 39/39 [==============================] - 138s 3s/step - loss: 1.4088 - accuracy: 0.4059 - val_loss: 1.3564 - val_accuracy: 0.4625
# Epoch 8/128
# 39/39 [==============================] - 139s 4s/step - loss: 1.4205 - accuracy: 0.4462 - val_loss: 1.4861 - val_accuracy: 0.4062
# Epoch 9/128
# 39/39 [==============================] - 137s 3s/step - loss: 1.2370 - accuracy: 0.4823 - val_loss: 2.6864 - val_accuracy: 0.2375
# Epoch 10/128
# 39/39 [==============================] - 138s 4s/step - loss: 1.3167 - accuracy: 0.5021 - val_loss: 1.1270 - val_accuracy: 0.5688
# Epoch 11/128
# 39/39 [==============================] - 137s 4s/step - loss: 1.5894 - accuracy: 0.5366 - val_loss: 0.9649 - val_accuracy: 0.5875
# Epoch 12/128
# 39/39 [==============================] - 137s 4s/step - loss: 1.0547 - accuracy: 0.6007 - val_loss: 1.4082 - val_accuracy: 0.5188
# Epoch 13/128
# 39/39 [==============================] - 138s 4s/step - loss: 1.0371 - accuracy: 0.6286 - val_loss: 1.0067 - val_accuracy: 0.6313
# Epoch 14/128
# 39/39 [==============================] - 134s 3s/step - loss: 1.1220 - accuracy: 0.6220 - val_loss: 1.0326 - val_accuracy: 0.6125
# Epoch 15/128
# 39/39 [==============================] - 134s 3s/step - loss: 0.9517 - accuracy: 0.6385 - val_loss: 1.6417 - val_accuracy: 0.5375
# Epoch 16/128
# 39/39 [==============================] - 137s 3s/step - loss: 1.0430 - accuracy: 0.6467 - val_loss: 0.7132 - val_accuracy: 0.7312
# Epoch 17/128
# 39/39 [==============================] - 140s 4s/step - loss: 0.8232 - accuracy: 0.6984 - val_loss: 1.6522 - val_accuracy: 0.4688
# Epoch 18/128
# 39/39 [==============================] - 139s 4s/step - loss: 1.3796 - accuracy: 0.6656 - val_loss: 0.6867 - val_accuracy: 0.7312
# Epoch 19/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.7967 - accuracy: 0.7124 - val_loss: 0.7632 - val_accuracy: 0.6938
# Epoch 20/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.8073 - accuracy: 0.7091 - val_loss: 0.9279 - val_accuracy: 0.6562
# Epoch 21/128
# 39/39 [==============================] - 141s 4s/step - loss: 0.8104 - accuracy: 0.7034 - val_loss: 0.7393 - val_accuracy: 0.7437
# Epoch 22/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.7857 - accuracy: 0.7231 - val_loss: 0.5341 - val_accuracy: 0.8250
# Epoch 23/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.8344 - accuracy: 0.6861 - val_loss: 0.7161 - val_accuracy: 0.7188
# Epoch 24/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.7821 - accuracy: 0.7362 - val_loss: 0.5963 - val_accuracy: 0.7937
# Epoch 25/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.7688 - accuracy: 0.7231 - val_loss: 0.9440 - val_accuracy: 0.6625
# Epoch 26/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.7502 - accuracy: 0.7354 - val_loss: 0.6980 - val_accuracy: 0.7375
# Epoch 27/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.6970 - accuracy: 0.7535 - val_loss: 0.7634 - val_accuracy: 0.7500
# Epoch 28/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.6986 - accuracy: 0.7551 - val_loss: 0.5009 - val_accuracy: 0.7875
# Epoch 29/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.6818 - accuracy: 0.7535 - val_loss: 0.6756 - val_accuracy: 0.7125
# Epoch 30/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.6111 - accuracy: 0.7888 - val_loss: 1.2806 - val_accuracy: 0.6250
# Epoch 31/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.6080 - accuracy: 0.7888 - val_loss: 0.7336 - val_accuracy: 0.7688
# Epoch 32/128
# 39/39 [==============================] - 141s 4s/step - loss: 0.6333 - accuracy: 0.7872 - val_loss: 0.4843 - val_accuracy: 0.7937
# Epoch 33/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.5323 - accuracy: 0.7970 - val_loss: 0.3475 - val_accuracy: 0.8875
# Epoch 34/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.6226 - accuracy: 0.7905 - val_loss: 0.7462 - val_accuracy: 0.7250
# Epoch 35/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.5220 - accuracy: 0.8151 - val_loss: 0.2558 - val_accuracy: 0.9187
# Epoch 36/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.5316 - accuracy: 0.8253 - val_loss: 0.3395 - val_accuracy: 0.8687
# Epoch 37/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.4929 - accuracy: 0.8316 - val_loss: 0.3268 - val_accuracy: 0.9000
# Epoch 38/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.4773 - accuracy: 0.8340 - val_loss: 0.1821 - val_accuracy: 0.9312
# Epoch 39/128
# 39/39 [==============================] - 135s 4s/step - loss: 0.4713 - accuracy: 0.8250 - val_loss: 0.3293 - val_accuracy: 0.8687
# Epoch 40/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.5328 - accuracy: 0.8381 - val_loss: 0.2420 - val_accuracy: 0.9125
# Epoch 41/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.4819 - accuracy: 0.8365 - val_loss: 0.3240 - val_accuracy: 0.8875
# Epoch 42/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.4329 - accuracy: 0.8447 - val_loss: 0.4425 - val_accuracy: 0.7875
# Epoch 43/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.4246 - accuracy: 0.8546 - val_loss: 0.4072 - val_accuracy: 0.8687
# Epoch 44/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3755 - accuracy: 0.8685 - val_loss: 0.2262 - val_accuracy: 0.9250
# Epoch 45/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.4272 - accuracy: 0.8611 - val_loss: 0.2221 - val_accuracy: 0.9125
# Epoch 46/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.3375 - accuracy: 0.8932 - val_loss: 0.2022 - val_accuracy: 0.9375
# Epoch 47/128
# 39/39 [==============================] - 140s 4s/step - loss: 0.3825 - accuracy: 0.8750 - val_loss: 0.2191 - val_accuracy: 0.9250
# Epoch 48/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3900 - accuracy: 0.8694 - val_loss: 0.1465 - val_accuracy: 0.9438
# Epoch 49/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.4597 - accuracy: 0.8652 - val_loss: 0.2809 - val_accuracy: 0.9000
# Epoch 50/128
# 39/39 [==============================] - 140s 4s/step - loss: 0.3582 - accuracy: 0.8899 - val_loss: 0.2621 - val_accuracy: 0.9187
# Epoch 51/128
# 39/39 [==============================] - 141s 4s/step - loss: 0.5347 - accuracy: 0.8614 - val_loss: 0.2374 - val_accuracy: 0.9062
# Epoch 52/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.4043 - accuracy: 0.8825 - val_loss: 0.4301 - val_accuracy: 0.8500
# Epoch 53/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.3133 - accuracy: 0.8981 - val_loss: 0.3150 - val_accuracy: 0.9000
# Epoch 54/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3026 - accuracy: 0.9022 - val_loss: 0.2451 - val_accuracy: 0.9250
# Epoch 55/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.4477 - accuracy: 0.8759 - val_loss: 0.1398 - val_accuracy: 0.9500
# Epoch 56/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.2992 - accuracy: 0.8989 - val_loss: 0.1812 - val_accuracy: 0.9250
# Epoch 57/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3284 - accuracy: 0.9096 - val_loss: 1.4534 - val_accuracy: 0.6375
# Epoch 58/128
# 39/39 [==============================] - 141s 4s/step - loss: 0.3795 - accuracy: 0.8891 - val_loss: 0.1974 - val_accuracy: 0.9187
# Epoch 59/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3087 - accuracy: 0.9096 - val_loss: 0.9350 - val_accuracy: 0.7812
# Epoch 60/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3158 - accuracy: 0.8915 - val_loss: 0.1942 - val_accuracy: 0.9187
# Epoch 61/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3281 - accuracy: 0.8956 - val_loss: 0.2774 - val_accuracy: 0.9000
# Epoch 62/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2679 - accuracy: 0.9228 - val_loss: 1.4325 - val_accuracy: 0.7312
# Epoch 63/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3519 - accuracy: 0.8948 - val_loss: 0.1434 - val_accuracy: 0.9438
# Epoch 64/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.3411 - accuracy: 0.8973 - val_loss: 0.2570 - val_accuracy: 0.9563
# Epoch 65/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3967 - accuracy: 0.9039 - val_loss: 0.1239 - val_accuracy: 0.9625
# Epoch 66/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2726 - accuracy: 0.9121 - val_loss: 1.0246 - val_accuracy: 0.6187
# Epoch 67/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2886 - accuracy: 0.9096 - val_loss: 0.2686 - val_accuracy: 0.9500
# Epoch 68/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3248 - accuracy: 0.9022 - val_loss: 0.1183 - val_accuracy: 0.9250
# Epoch 69/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2922 - accuracy: 0.9121 - val_loss: 0.0943 - val_accuracy: 0.9750
# Epoch 70/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.2783 - accuracy: 0.9121 - val_loss: 0.2602 - val_accuracy: 0.8938
# Epoch 71/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.3091 - accuracy: 0.9088 - val_loss: 0.2259 - val_accuracy: 0.9312
# Epoch 72/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2688 - accuracy: 0.9236 - val_loss: 0.1476 - val_accuracy: 0.9438
# Epoch 73/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.2700 - accuracy: 0.9260 - val_loss: 0.1211 - val_accuracy: 0.9438
# Epoch 74/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3315 - accuracy: 0.8956 - val_loss: 0.2056 - val_accuracy: 0.9438
# Epoch 75/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.2543 - accuracy: 0.9195 - val_loss: 0.2022 - val_accuracy: 0.9125
# Epoch 76/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.2185 - accuracy: 0.9359 - val_loss: 1.1006 - val_accuracy: 0.7188
# Epoch 77/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.3696 - accuracy: 0.9039 - val_loss: 0.1320 - val_accuracy: 0.9625
# Epoch 78/128
# 39/39 [==============================] - 134s 3s/step - loss: 0.5602 - accuracy: 0.9228 - val_loss: 0.0802 - val_accuracy: 0.9688
# Epoch 79/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.1779 - accuracy: 0.9433 - val_loss: 0.3053 - val_accuracy: 0.9125
# Epoch 80/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.3616 - accuracy: 0.8989 - val_loss: 0.0799 - val_accuracy: 0.9750
# Epoch 81/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.3311 - accuracy: 0.9277 - val_loss: 0.1221 - val_accuracy: 0.9875
# Epoch 82/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2739 - accuracy: 0.9302 - val_loss: 0.3879 - val_accuracy: 0.9062
# Epoch 83/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3215 - accuracy: 0.9178 - val_loss: 0.2524 - val_accuracy: 0.9312
# Epoch 84/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.3482 - accuracy: 0.8866 - val_loss: 0.1324 - val_accuracy: 0.9500
# Epoch 85/128
# 39/39 [==============================] - 134s 3s/step - loss: 0.2827 - accuracy: 0.9277 - val_loss: 0.3299 - val_accuracy: 0.9125
# Epoch 86/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2927 - accuracy: 0.9154 - val_loss: 0.1685 - val_accuracy: 0.9375
# Epoch 87/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.2295 - accuracy: 0.9285 - val_loss: 0.0996 - val_accuracy: 0.9688
# Epoch 88/128
# 39/39 [==============================] - 140s 4s/step - loss: 0.2406 - accuracy: 0.9326 - val_loss: 0.6239 - val_accuracy: 0.9000
# Epoch 89/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2332 - accuracy: 0.9384 - val_loss: 0.1663 - val_accuracy: 0.9438
# Epoch 90/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.4520 - accuracy: 0.9030 - val_loss: 0.8481 - val_accuracy: 0.8375
# Epoch 91/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2073 - accuracy: 0.9441 - val_loss: 0.4880 - val_accuracy: 0.9250
# Epoch 92/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.3056 - accuracy: 0.9211 - val_loss: 0.3033 - val_accuracy: 0.9438
# Epoch 93/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3414 - accuracy: 0.9187 - val_loss: 0.2742 - val_accuracy: 0.9563
# Epoch 94/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2120 - accuracy: 0.9343 - val_loss: 0.2992 - val_accuracy: 0.8750
# Epoch 95/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3280 - accuracy: 0.9137 - val_loss: 0.1835 - val_accuracy: 0.9500
# Epoch 96/128
# 39/39 [==============================] - 132s 3s/step - loss: 0.2552 - accuracy: 0.9252 - val_loss: 0.1802 - val_accuracy: 0.9625
# Epoch 97/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.2828 - accuracy: 0.9170 - val_loss: 0.1082 - val_accuracy: 0.9500
# Epoch 98/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.2496 - accuracy: 0.9302 - val_loss: 0.2536 - val_accuracy: 0.9125
# Epoch 99/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2638 - accuracy: 0.9285 - val_loss: 0.2034 - val_accuracy: 0.9375
# Epoch 100/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.2636 - accuracy: 0.9260 - val_loss: 0.5796 - val_accuracy: 0.8313
# Epoch 101/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.3566 - accuracy: 0.9195 - val_loss: 0.1329 - val_accuracy: 0.9625
# Epoch 102/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.2247 - accuracy: 0.9408 - val_loss: 0.3245 - val_accuracy: 0.9062
# Epoch 103/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.2882 - accuracy: 0.9236 - val_loss: 0.0633 - val_accuracy: 0.9812
# Epoch 104/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3382 - accuracy: 0.9137 - val_loss: 0.1171 - val_accuracy: 0.9563
# Epoch 105/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.3517 - accuracy: 0.9154 - val_loss: 0.1066 - val_accuracy: 0.9688
# Epoch 106/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2306 - accuracy: 0.9433 - val_loss: 0.2245 - val_accuracy: 0.9125
# Epoch 107/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.2549 - accuracy: 0.9178 - val_loss: 0.5038 - val_accuracy: 0.9187
# Epoch 108/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3202 - accuracy: 0.9170 - val_loss: 0.4524 - val_accuracy: 0.9062
# Epoch 109/128
# 39/39 [==============================] - 136s 3s/step - loss: 0.3810 - accuracy: 0.9104 - val_loss: 0.3206 - val_accuracy: 0.9125
# Epoch 110/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.2818 - accuracy: 0.9228 - val_loss: 0.0831 - val_accuracy: 0.9750
# Epoch 111/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.2732 - accuracy: 0.9334 - val_loss: 0.2482 - val_accuracy: 0.9500
# Epoch 112/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3479 - accuracy: 0.9203 - val_loss: 0.3067 - val_accuracy: 0.9125
# Epoch 113/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.2594 - accuracy: 0.9449 - val_loss: 0.0821 - val_accuracy: 0.9688
# Epoch 114/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.4257 - accuracy: 0.9137 - val_loss: 0.0732 - val_accuracy: 0.9688
# Epoch 115/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2666 - accuracy: 0.9392 - val_loss: 0.1662 - val_accuracy: 0.9438
# Epoch 116/128
# 39/39 [==============================] - 140s 4s/step - loss: 0.3593 - accuracy: 0.9228 - val_loss: 0.2563 - val_accuracy: 0.9187
# Epoch 117/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3639 - accuracy: 0.9162 - val_loss: 0.2388 - val_accuracy: 0.9250
# Epoch 118/128
# 39/39 [==============================] - 139s 4s/step - loss: 0.3468 - accuracy: 0.9219 - val_loss: 0.3293 - val_accuracy: 0.9250
# Epoch 119/128
# 39/39 [==============================] - 135s 3s/step - loss: 0.2507 - accuracy: 0.9252 - val_loss: 0.0955 - val_accuracy: 0.9812
# Epoch 120/128
# 39/39 [==============================] - 134s 4s/step - loss: 0.2353 - accuracy: 0.9384 - val_loss: 0.2217 - val_accuracy: 0.9563
# Epoch 121/128
# 39/39 [==============================] - 137s 4s/step - loss: 0.2587 - accuracy: 0.9392 - val_loss: 0.1458 - val_accuracy: 0.9625
# Epoch 122/128
# 39/39 [==============================] - 134s 3s/step - loss: 0.3778 - accuracy: 0.9055 - val_loss: 0.1475 - val_accuracy: 0.9563
# Epoch 123/128
# 39/39 [==============================] - 134s 3s/step - loss: 0.3203 - accuracy: 0.9121 - val_loss: 0.1126 - val_accuracy: 0.9563
# Epoch 124/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.2873 - accuracy: 0.9195 - val_loss: 0.4261 - val_accuracy: 0.9438
# Epoch 125/128
# 39/39 [==============================] - 137s 3s/step - loss: 0.3658 - accuracy: 0.9129 - val_loss: 0.1294 - val_accuracy: 0.9625
# Epoch 126/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.3756 - accuracy: 0.9285 - val_loss: 0.0986 - val_accuracy: 0.9750
# Epoch 127/128
# 39/39 [==============================] - 141s 4s/step - loss: 0.2790 - accuracy: 0.9318 - val_loss: 0.1952 - val_accuracy: 0.9625
# Epoch 128/128
# 39/39 [==============================] - 138s 4s/step - loss: 0.4564 - accuracy: 0.9095 - val_loss: 0.1445 - val_accuracy: 0.9312

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = model.predict(val_dataset, steps=len(val_dataset))
predicted_labels = np.argmax(predictions, axis=1)
true_labels = val_dataset.classes
cm = confusion_matrix(true_labels, predicted_labels)

# Create a seaborn heatmap
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 6/6 [==============================] - 4s 570ms/step

# %%
model.save('attempt_005.h5')

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# i think 60 epochs is enough
