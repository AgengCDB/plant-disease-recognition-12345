# %% [markdown]
# ##### Delete folder before starting

# %%
# i asked gpt to write this code

import shutil
import os

def delete_folder(folder_path):
    if os.path.exists(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f"Folder '{folder_path}' deleted successfully.")
        except OSError as e:
            print(f"Error: {e}")
    else:
        print(f"Folder '{folder_path}' does not exist.")

# %%
# train
folder_to_delete = "Apple/train"
delete_folder(folder_to_delete)

# val
folder_to_delete = "Apple/val"
delete_folder(folder_to_delete)
# Out:
# Folder 'Apple/train' deleted successfully.
# Folder 'Apple/val' deleted successfully.

# %% [markdown]
# # Code

# %%
import os 
dir = 'Apple' # this read fodler
print(os.listdir(dir))
# Out:
# ['AlternariaBoltch', 'AppleScab', 'BlackRot', 'CedarAppleRust', 'Disease', 'Healthy', 'Rust']

# %%
# labels from folder in directory yoooo
labels = os.listdir(dir)
labels.remove("Disease")
labels
# Out:
# ['AlternariaBoltch',
#  'AppleScab',
#  'BlackRot',
#  'CedarAppleRust',
#  'Healthy',
#  'Rust']

# %%
# import
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import scipy as sp
import itertools
import zipfile
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, MaxPool2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# m8 delete later, should check on it

# %%
'''
Abbreviation (so i don't need to write long name)

AlternariaBoltch = boltch
AppleScab = scab
BlackRot = brot
CedarAppleRust = carust
Healthy = healthy
Rust = rust
'''

boltch_dir = os.path.join(dir, 'AlternariaBoltch')
scab_dir = os.path.join(dir, 'AppleScab')
brot_dir = os.path.join(dir, 'BlackRot')
carust_dir = os.path.join(dir, 'CedarAppleRust')
healthy_dir = os.path.join(dir, 'Healthy')
rust_dir = os.path.join(dir, 'Rust')

boltch = os.listdir(boltch_dir)
scab = os.listdir(scab_dir)
brot = os.listdir(brot_dir)
carust = os.listdir(carust_dir)
healthy = os.listdir(healthy_dir)
rust = os.listdir(rust_dir)

# %%
import random
import shutil

# Function split
def split_data(src, train_dst, val_dst, split_ratio=0.6):
    files = os.listdir(src)
    random.shuffle(files)

    split_index = int(len(files) * split_ratio)

    train_files = files[:split_index]
    val_files = files[split_index:]

    for file in train_files:
        shutil.copy(os.path.join(src, file), os.path.join(train_dst, file))

    for file in val_files:
        shutil.copy(os.path.join(src, file), os.path.join(val_dst, file))

# %%
train_dir = os.path.join(dir, 'train')
val_dir = os.path.join(dir, 'val')

# only use it once
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

os.listdir('Apple/train')
os.listdir('Apple/val')
# Out:
# []

# %%
# only use it once
for i in labels:
    os.makedirs(os.path.join(train_dir, i), exist_ok=True)
    os.makedirs(os.path.join(val_dir, i), exist_ok=True)

# %%
# Splitting the data, i hope someone made a better code for this :)
split_data(boltch_dir, os.path.join(train_dir, 'AlternariaBoltch'), os.path.join(val_dir, 'AlternariaBoltch'))
split_data(scab_dir, os.path.join(train_dir, 'AppleScab'), os.path.join(val_dir, 'AppleScab'))
split_data(brot_dir, os.path.join(train_dir, 'BlackRot'), os.path.join(val_dir, 'BlackRot'))
split_data(carust_dir, os.path.join(train_dir, 'CedarAppleRust'), os.path.join(val_dir, 'CedarAppleRust'))
split_data(healthy_dir, os.path.join(train_dir, 'Healthy'), os.path.join(val_dir, 'Healthy'))
split_data(rust_dir, os.path.join(train_dir, 'Rust'), os.path.join(val_dir, 'Rust'))

# %%
# ImageDataGenerator
train_gen = ImageDataGenerator(rescale=1.0/256.0, 
                            zoom_range=0.4, 
                            rotation_range=30,
                            horizontal_flip=True, 
                            vertical_flip=True, 
                            shear_range=0.3, 
                            fill_mode='nearest',
                            width_shift_range=0.2, 
                            height_shift_range=0.2, 
                            validation_split=0.2)
val_gen = ImageDataGenerator(rescale=1.0/256.0,
                            validation_split=0.2)

# %%
train_dataset = train_gen.flow_from_directory(train_dir, 
                                            target_size=(256, 256), 
                                            color_mode="rgb",
                                            class_mode='categorical', 
                                            batch_size=32)
val_dataset = val_gen.flow_from_directory(val_dir, 
                                        target_size=(256, 256), 
                                        color_mode="rgb",
                                        class_mode='categorical', 
                                        batch_size=32,
                                        subset='validation')
# Out:
# Found 1702 images belonging to 6 classes.
# Found 225 images belonging to 6 classes.

# %%
print(train_dataset.class_indices)
print(val_dataset.class_indices)
# Out:
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}
# {'AlternariaBoltch': 0, 'AppleScab': 1, 'BlackRot': 2, 'CedarAppleRust': 3, 'Healthy': 4, 'Rust': 5}

# %%
NUM_TRAIN_DATA = train_dataset.n
NUM_VALID_DATA = val_dataset.n

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=32, activation='relu', input_shape=(256, 256, 3), padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=32, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=64, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=128, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=256, activation='relu', padding='same', kernel_size=(3, 3)),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    # Flatten
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='softmax'),
])

monitor = EarlyStopping(monitor='val_accuracy',
                        patience=2,
                        verbose=1,
                        mode='max',
                        restore_best_weights=True)

# %%
# don't use this one

# model = Sequential()

# model.add(Conv2D(16, kernel_size=3, activation='relu', input_shape=(256, 256, 3)))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(32, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(64, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Conv2D(128, kernel_size=3, activation='relu'))
# model.add(MaxPool2D(2,2))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(7, activation='softmax'))

# model.summary()

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 256)       590080
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 256)               16777472
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 17,983,398
# Trainable params: 17,983,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 64
# a

# %%
history = model.fit(train_dataset, 
                    steps_per_epoch=NUM_TRAIN_DATA//BATCH_SIZE,
                    validation_data=val_dataset,
                    validation_steps=5,
                    epochs=EPOCHS,
                    verbose=1)
# Out:
# Epoch 1/64
# 53/53 [==============================] - 211s 4s/step - loss: 4.7412 - accuracy: 0.4156 - val_loss: 1.5353 - val_accuracy: 0.4437
# Epoch 2/64
# 53/53 [==============================] - 184s 3s/step - loss: 1.4624 - accuracy: 0.4587 - val_loss: 1.6165 - val_accuracy: 0.4313
# Epoch 3/64
# 53/53 [==============================] - 184s 3s/step - loss: 1.4332 - accuracy: 0.4766 - val_loss: 1.3624 - val_accuracy: 0.5312
# Epoch 4/64
# 53/53 [==============================] - 182s 3s/step - loss: 1.3965 - accuracy: 0.4832 - val_loss: 1.5079 - val_accuracy: 0.4563
# Epoch 5/64
# 53/53 [==============================] - 184s 3s/step - loss: 1.4436 - accuracy: 0.4856 - val_loss: 1.4558 - val_accuracy: 0.4812
# Epoch 6/64
# 53/53 [==============================] - 184s 3s/step - loss: 1.4150 - accuracy: 0.5000 - val_loss: 1.2992 - val_accuracy: 0.5188
# Epoch 7/64
# 53/53 [==============================] - 185s 3s/step - loss: 1.1818 - accuracy: 0.5425 - val_loss: 1.3059 - val_accuracy: 0.4437
# Epoch 8/64
# 53/53 [==============================] - 182s 3s/step - loss: 1.1356 - accuracy: 0.5725 - val_loss: 1.1272 - val_accuracy: 0.5813
# Epoch 9/64
# 53/53 [==============================] - 185s 3s/step - loss: 1.0561 - accuracy: 0.5958 - val_loss: 1.6929 - val_accuracy: 0.4563
# Epoch 10/64
# 53/53 [==============================] - 185s 3s/step - loss: 1.0083 - accuracy: 0.6317 - val_loss: 0.9619 - val_accuracy: 0.6938
# Epoch 11/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.9307 - accuracy: 0.6659 - val_loss: 0.8486 - val_accuracy: 0.6812
# Epoch 12/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.8761 - accuracy: 0.6784 - val_loss: 0.8746 - val_accuracy: 0.6875
# Epoch 13/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.8960 - accuracy: 0.6653 - val_loss: 0.7364 - val_accuracy: 0.7188
# Epoch 14/64
# 53/53 [==============================] - 187s 4s/step - loss: 0.8402 - accuracy: 0.6988 - val_loss: 0.7885 - val_accuracy: 0.7188
# Epoch 15/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.8095 - accuracy: 0.6922 - val_loss: 0.8628 - val_accuracy: 0.6500
# Epoch 16/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.7923 - accuracy: 0.7162 - val_loss: 0.7877 - val_accuracy: 0.7000
# Epoch 17/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.7457 - accuracy: 0.7281 - val_loss: 0.7013 - val_accuracy: 0.7250
# Epoch 18/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.7404 - accuracy: 0.7395 - val_loss: 0.6765 - val_accuracy: 0.7312
# Epoch 19/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.7352 - accuracy: 0.7347 - val_loss: 0.5923 - val_accuracy: 0.7812
# Epoch 20/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.6496 - accuracy: 0.7527 - val_loss: 0.7004 - val_accuracy: 0.7125
# Epoch 21/64
# 53/53 [==============================] - 184s 4s/step - loss: 0.6485 - accuracy: 0.7802 - val_loss: 0.9072 - val_accuracy: 0.6875
# Epoch 22/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.6155 - accuracy: 0.7671 - val_loss: 0.6190 - val_accuracy: 0.8000
# Epoch 23/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.7573 - accuracy: 0.7808 - val_loss: 0.5616 - val_accuracy: 0.7625
# Epoch 24/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.6247 - accuracy: 0.7766 - val_loss: 0.5155 - val_accuracy: 0.7500
# Epoch 25/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.6030 - accuracy: 0.7898 - val_loss: 0.7314 - val_accuracy: 0.7625
# Epoch 26/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.5637 - accuracy: 0.7892 - val_loss: 0.8136 - val_accuracy: 0.7375
# Epoch 27/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.5330 - accuracy: 0.8012 - val_loss: 0.7747 - val_accuracy: 0.7750
# Epoch 28/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.5593 - accuracy: 0.8096 - val_loss: 0.5451 - val_accuracy: 0.8062
# Epoch 29/64
# 53/53 [==============================] - 188s 4s/step - loss: 0.5445 - accuracy: 0.8078 - val_loss: 0.4035 - val_accuracy: 0.8313
# Epoch 30/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.5127 - accuracy: 0.8084 - val_loss: 0.9880 - val_accuracy: 0.7000
# Epoch 31/64
# 53/53 [==============================] - 190s 4s/step - loss: 0.5186 - accuracy: 0.8156 - val_loss: 0.4108 - val_accuracy: 0.8500
# Epoch 32/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.5046 - accuracy: 0.8120 - val_loss: 0.6338 - val_accuracy: 0.7563
# Epoch 33/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.5009 - accuracy: 0.8192 - val_loss: 0.5733 - val_accuracy: 0.8000
# Epoch 34/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.4816 - accuracy: 0.8216 - val_loss: 0.6667 - val_accuracy: 0.7937
# Epoch 35/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.5331 - accuracy: 0.8246 - val_loss: 0.6083 - val_accuracy: 0.7563
# Epoch 36/64
# 53/53 [==============================] - 182s 3s/step - loss: 0.4657 - accuracy: 0.8305 - val_loss: 0.3548 - val_accuracy: 0.8562
# Epoch 37/64
# 53/53 [==============================] - 195s 4s/step - loss: 0.4738 - accuracy: 0.8287 - val_loss: 0.5200 - val_accuracy: 0.8250
# Epoch 38/64
# 53/53 [==============================] - 195s 4s/step - loss: 0.4848 - accuracy: 0.8401 - val_loss: 0.6198 - val_accuracy: 0.7812
# Epoch 39/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.4656 - accuracy: 0.8329 - val_loss: 0.7241 - val_accuracy: 0.7625
# Epoch 40/64
# 53/53 [==============================] - 183s 3s/step - loss: 0.4306 - accuracy: 0.8473 - val_loss: 0.4761 - val_accuracy: 0.8125
# Epoch 41/64
# 53/53 [==============================] - 186s 3s/step - loss: 0.4995 - accuracy: 0.8198 - val_loss: 0.8867 - val_accuracy: 0.7188
# Epoch 42/64
# 53/53 [==============================] - 182s 3s/step - loss: 0.4889 - accuracy: 0.8353 - val_loss: 0.4973 - val_accuracy: 0.8313
# Epoch 43/64
# 53/53 [==============================] - 197s 4s/step - loss: 0.4643 - accuracy: 0.8461 - val_loss: 0.5944 - val_accuracy: 0.8000
# Epoch 44/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.4470 - accuracy: 0.8395 - val_loss: 0.4921 - val_accuracy: 0.8438
# Epoch 45/64
# 53/53 [==============================] - 187s 4s/step - loss: 0.4885 - accuracy: 0.8341 - val_loss: 0.4562 - val_accuracy: 0.8562
# Epoch 46/64
# 53/53 [==============================] - 178s 3s/step - loss: 0.4792 - accuracy: 0.8299 - val_loss: 0.4400 - val_accuracy: 0.8438
# Epoch 47/64
# 53/53 [==============================] - 184s 3s/step - loss: 0.3770 - accuracy: 0.8617 - val_loss: 0.5950 - val_accuracy: 0.7812
# Epoch 48/64
# 53/53 [==============================] - 187s 4s/step - loss: 0.4254 - accuracy: 0.8347 - val_loss: 1.0447 - val_accuracy: 0.8125
# Epoch 49/64
# 53/53 [==============================] - 198s 4s/step - loss: 0.4920 - accuracy: 0.8329 - val_loss: 1.4216 - val_accuracy: 0.7563
# Epoch 50/64
# 53/53 [==============================] - 185s 3s/step - loss: 0.4506 - accuracy: 0.8443 - val_loss: 0.6167 - val_accuracy: 0.8125
# Epoch 51/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.4073 - accuracy: 0.8563 - val_loss: 0.6676 - val_accuracy: 0.8188
# Epoch 52/64
# 53/53 [==============================] - 175s 3s/step - loss: 0.4367 - accuracy: 0.8545 - val_loss: 0.6701 - val_accuracy: 0.8062
# Epoch 53/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.4454 - accuracy: 0.8629 - val_loss: 0.5957 - val_accuracy: 0.8500
# Epoch 54/64
# 53/53 [==============================] - 176s 3s/step - loss: 0.4259 - accuracy: 0.8575 - val_loss: 0.8457 - val_accuracy: 0.7500
# Epoch 55/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.4032 - accuracy: 0.8593 - val_loss: 0.3672 - val_accuracy: 0.8813
# Epoch 56/64
# 53/53 [==============================] - 170s 3s/step - loss: 0.3911 - accuracy: 0.8701 - val_loss: 0.4776 - val_accuracy: 0.8062
# Epoch 57/64
# 53/53 [==============================] - 174s 3s/step - loss: 0.4905 - accuracy: 0.8611 - val_loss: 0.3495 - val_accuracy: 0.8687
# Epoch 58/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.3477 - accuracy: 0.8832 - val_loss: 0.8759 - val_accuracy: 0.8313
# Epoch 59/64
# 53/53 [==============================] - 172s 3s/step - loss: 0.3496 - accuracy: 0.8832 - val_loss: 0.8921 - val_accuracy: 0.7750
# Epoch 60/64
# 53/53 [==============================] - 174s 3s/step - loss: 0.3633 - accuracy: 0.8725 - val_loss: 0.2720 - val_accuracy: 0.9000
# Epoch 61/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.4163 - accuracy: 0.8731 - val_loss: 0.5572 - val_accuracy: 0.8625
# Epoch 62/64
# 53/53 [==============================] - 173s 3s/step - loss: 0.4030 - accuracy: 0.8731 - val_loss: 0.4260 - val_accuracy: 0.8188
# Epoch 63/64
# 53/53 [==============================] - 171s 3s/step - loss: 0.4717 - accuracy: 0.8677 - val_loss: 0.3086 - val_accuracy: 0.8625
# Epoch 64/64
# 53/53 [==============================] - 172s 3s/step - loss: 0.3762 - accuracy: 0.8599 - val_loss: 0.4982 - val_accuracy: 0.8625

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = model.predict(val_dataset, steps=len(val_dataset))
predicted_labels = np.argmax(predictions, axis=1)
true_labels = val_dataset.classes
cm = confusion_matrix(true_labels, predicted_labels)

# Create a seaborn heatmap
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 8/8 [==============================] - 5s 586ms/step

# %%
model.save('attempt_004.h5')

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
